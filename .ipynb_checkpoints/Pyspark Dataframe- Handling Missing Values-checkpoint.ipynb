# %%
import csv

rows = [
    (25, 2, 45000),
    (32, 7, 62000),
    ("", 5, 54000),
    (45, "", 90000),
    (29, 4, ""),
    (38, 12, 78000),
    (41, "", 85000),
    ("", 3, 50000),
    (27, 1, 42000),
    (50, 25, ""),
    (36, 10, 70000),
    (31, "", 61000),
    ("", 6, 56000),
    (42, 15, ""),
    (28, 2, 48000),
    (34, 8, 65000),
    (39, "", 80000),
    ("", 4, 52000),
    (46, 20, ""),
    (30, 5, 58000),
]

with open("sample_pyspark_nulls.csv", "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["age", "experience", "salary"])
    w.writerows(rows)

print("Wrote sample_pyspark_nulls.csv")
# Out:
# Wrote sample_pyspark_nulls.csv
