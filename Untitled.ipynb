# %%
# !pip install pyspark

# %%
import pyspark

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name": ["Alice", "Mohamed", "Sara", "Youssef", "Lina"],
    "age": [24, 31, 28, 22, 35]
})

df.to_csv("cheet.csv", index=False)

# %%
pd.read_csv("cheet.csv")
# Out:
#       name  age
# 0    Alice   24
# 1  Mohamed   31
# 2     Sara   28
# 3  Youssef   22
# 4     Lina   35

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("learn").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-52EP7TM:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>learn</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv("cheet.csv")

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +-------+---+
# |    _c0|_c1|
# +-------+---+
# |   name|age|
# |  Alice| 24|
# |Mohamed| 31|
# |   Sara| 28|
# |Youssef| 22|
# |   Lina| 35|
# +-------+---+

# %%
df_spark = spark.read.option('header','true').csv("cheet.csv")

# %%
df_spark
# Out:
# DataFrame[name: string, age: string]

# %%
df_spark.show()
# Out:
# +-------+---+
# |   name|age|
# +-------+---+
# |  Alice| 24|
# |Mohamed| 31|
# |   Sara| 28|
# |Youssef| 22|
# |   Lina| 35|
# +-------+---+
